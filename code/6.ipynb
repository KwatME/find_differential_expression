# %%
# %load_ext autoreload
# %autoreload 2

# %%
from __init__ import *

# %%
nu_fe_sa = pd.read_csv("../output/number_feature_sample.tsv", "\t", index_col=0)

se_fe_ = kraft.gmt.read(kraft.path.list("../input/set/"))

st_se_in = pd.read_csv("../output/statistic_set_information.tsv", "\t", index_col=0)

# %%
sc_se_sa = kraft.score_set.score_samples_and_sets(
    nu_fe_sa,
    {se: se_fe_[se] for se in st_se_in.index[st_se_in.loc[:, "Selected"]]},
    n_jo=SETTING["n_jo"],
)

sc_se_sa.to_csv("../output/score_set_sample.tsv", "\t")

sc_se_sa
# Out:
#                                                           S1        S2  \
# Set
# BLANCO_MELO_SARS_COV_1_INFECTION_MCR5_CELLS_UP      0.172425  0.042456
# BLANCO_MELO_COVID19_SARS_COV_2_POS_PATIENT_LUNG...  0.194783  0.199356
# BUFFA_HYPOXIA_METAGENE                              0.156390  0.083031
# KORKOLA_EMBRYONAL_CARCINOMA_UP                      0.211372  0.265594
# KORKOLA_TERATOMA_UP                                 0.154131  0.265871
# ...                                                      ...       ...
# IPA_MED28_DN                                        0.189916 -0.094224
# IPA_HIF1AN_DN                                       0.012628  0.018986
# IPA_KDM5B_UP                                        0.317335  0.194560
# IPA_KDM1A_DN                                       -0.186768 -0.092568
# IPA_HDAC2_UP                                       -0.082993 -0.103833
#
#                                                           S3        S4  \
# Set
# BLANCO_MELO_SARS_COV_1_INFECTION_MCR5_CELLS_UP      0.007807  0.169966
# BLANCO_MELO_COVID19_SARS_COV_2_POS_PATIENT_LUNG...  0.192201  0.238130
# BUFFA_HYPOXIA_METAGENE                              0.138691  0.165700
# KORKOLA_EMBRYONAL_CARCINOMA_UP                      0.209494  0.317547
# KORKOLA_TERATOMA_UP                                 0.163745  0.140137
# ...                                                      ...       ...
# IPA_MED28_DN                                        0.206480  0.158619
# IPA_HIF1AN_DN                                      -0.090305  0.351018
# IPA_KDM5B_UP                                        0.187824  0.167550
# IPA_KDM1A_DN                                        0.006548 -0.011207
# IPA_HDAC2_UP                                       -0.120993 -0.070609
#
#                                                           S5        S6  \
# Set
# BLANCO_MELO_SARS_COV_1_INFECTION_MCR5_CELLS_UP      0.018018  0.154079
# BLANCO_MELO_COVID19_SARS_COV_2_POS_PATIENT_LUNG...  0.185999  0.239059
# BUFFA_HYPOXIA_METAGENE                              0.075085  0.058147
# KORKOLA_EMBRYONAL_CARCINOMA_UP                      0.200365  0.311740
# KORKOLA_TERATOMA_UP                                 0.267494  0.264094
# ...                                                      ...       ...
# IPA_MED28_DN                                        0.168759  0.134346
# IPA_HIF1AN_DN                                      -0.008035  0.384289
# IPA_KDM5B_UP                                        0.171110  0.295039
# IPA_KDM1A_DN                                       -0.060988 -0.100496
# IPA_HDAC2_UP                                       -0.044510 -0.003429
#
#                                                           S7        S8
# Set
# BLANCO_MELO_SARS_COV_1_INFECTION_MCR5_CELLS_UP      0.073746  0.125614
# BLANCO_MELO_COVID19_SARS_COV_2_POS_PATIENT_LUNG...  0.233982  0.215684
# BUFFA_HYPOXIA_METAGENE                              0.131702  0.122818
# KORKOLA_EMBRYONAL_CARCINOMA_UP                      0.307961  0.320135
# KORKOLA_TERATOMA_UP                                 0.260688  0.269951
# ...                                                      ...       ...
# IPA_MED28_DN                                        0.190222  0.197660
# IPA_HIF1AN_DN                                      -0.000182 -0.082298
# IPA_KDM5B_UP                                        0.183633  0.174242
# IPA_KDM1A_DN                                        0.186569 -0.022750
# IPA_HDAC2_UP                                       -0.029393 -0.140570
#
# [11003 rows x 8 columns]

# %%
sc_se_sa.reindex(SETTING["se_"])
# Out:
#                                                           S1        S2  \
# Set
# HP_APNEIC_EPISODES_PRECIPITATED_BY_ILLNESS_FATI...  0.001518 -0.033901
# HP_FATIGUE                                          0.109220  0.094092
# HP_CHRONIC_FATIGUE                                  0.257586  0.229713
# CD4+ in Celiac Disease 1                            0.043665  0.050664
# CD4+ in Celiac Disease 2                            0.052844  0.029723
#
#                                                           S3        S4  \
# Set
# HP_APNEIC_EPISODES_PRECIPITATED_BY_ILLNESS_FATI... -0.077096  0.216314
# HP_FATIGUE                                          0.079714  0.101029
# HP_CHRONIC_FATIGUE                                  0.264013  0.257474
# CD4+ in Celiac Disease 1                            0.002439  0.020811
# CD4+ in Celiac Disease 2                            0.012396  0.015184
#
#                                                           S5        S6  \
# Set
# HP_APNEIC_EPISODES_PRECIPITATED_BY_ILLNESS_FATI... -0.119257 -0.094485
# HP_FATIGUE                                          0.105355  0.107260
# HP_CHRONIC_FATIGUE                                  0.263582  0.250705
# CD4+ in Celiac Disease 1                            0.076452  0.019612
# CD4+ in Celiac Disease 2                            0.074331  0.025462
#
#                                                           S7        S8
# Set
# HP_APNEIC_EPISODES_PRECIPITATED_BY_ILLNESS_FATI...  0.182183 -0.135521
# HP_FATIGUE                                          0.122367  0.108213
# HP_CHRONIC_FATIGUE                                  0.257173  0.224753
# CD4+ in Celiac Disease 1                            0.064553  0.032037
# CD4+ in Celiac Disease 2                            0.092846  0.061081
